# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image_as_array = mpimg.imread('dog.jpg')

# %%
image_as_array.shape  ####(H, W,C)
# Out:
# (480, 768, 3)

# %%
plt.imshow(image_as_array)

# %%
(h,w,c) = image_as_array.shape

# %%
c
# Out:
# 3

# %%
image_as_array2d = image_as_array.reshape(h*w, c)

# %%
image_as_array2d
# Out:
# array([[ 77,  27,  18],
#        [ 79,  29,  20],
#        [ 80,  32,  22],
#        ...,
#        [200, 203, 208],
#        [199, 204, 208],
#        [199, 204, 208]], dtype=uint8)

# %%
len(image_as_array2d.shape)
# Out:
# 2

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
labels
# Out:
# array([0, 0, 0, ..., 4, 4, 4])

# %%
model.cluster_centers_
# Out:
# array([[ 62.69918548,  37.46502518,  28.40207051],
#        [231.47087321, 237.48038327, 241.6731141 ],
#        [175.76642303, 115.85092482,  85.04673329],
#        [134.96726695, 125.84379237, 125.36627119],
#        [208.31255001, 201.70086785, 200.3730381 ],
#        [127.49022331,  75.67396514,  53.05437092]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[ 63,  37,  28],
#        [231, 237, 242],
#        [176, 116,  85],
#        [135, 126, 125],
#        [208, 202, 200],
#        [127,  76,  53]])

# %%
labels
# Out:
# array([0, 0, 0, ..., 4, 4, 4])

# %%
rgb_codes[labels]
# Out:
# array([[ 63,  37,  28],
#        [ 63,  37,  28],
#        [ 63,  37,  28],
#        ...,
#        [208, 202, 200],
#        [208, 202, 200],
#        [208, 202, 200]])

# %%
image_as_array2d
# Out:
# array([[ 77,  27,  18],
#        [ 79,  29,  20],
#        [ 80,  32,  22],
#        ...,
#        [200, 203, 208],
#        [199, 204, 208],
#        [199, 204, 208]], dtype=uint8)

# %%
quantized_image = np.reshape(rgb_codes[labels],(h,w,c))

# %%
plt.imshow(quantized_image)
