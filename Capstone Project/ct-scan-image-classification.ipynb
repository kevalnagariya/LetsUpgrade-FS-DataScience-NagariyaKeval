# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '../input/sarscov2-ctscan-dataset'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                      File  DiseaseID Disease Type
# 0   COVID/Covid (230).png          0        COVID
# 1  COVID/Covid (1195).png          0        COVID
# 2   COVID/Covid (182).png          0        COVID
# 3   COVID/Covid (817).png          0        COVID
# 4   COVID/Covid (631).png          0        COVID

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                             File  DiseaseID Disease Type
# 0           COVID/Covid (54).png          0        COVID
# 1         COVID/Covid (1035).png          0        COVID
# 2   non-COVID/Non-Covid (21).png          1    non-COVID
# 3  non-COVID/Non-Covid (248).png          1    non-COVID
# 4          COVID/Covid (409).png          0        COVID

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 8))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('COVID', 3, 3)

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 8))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('non-COVID', 3, 3)

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2481it [00:36, 68.81it/s]
# Train Shape: (2481, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)
print(Y_train.shape)
# Out:
# (2481, 2)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
print(f'X_train:',X_train.shape)
print(f'X_val:',X_val.shape)
print(f'Y_train:',Y_train.shape)
print(f'Y_val:',Y_val.shape)
# Out:
# X_train: (1984, 64, 64, 3)
# X_val: (497, 64, 64, 3)
# Y_train: (1984, 2)
# Y_val: (497, 2)

# %%
EPOCHS = 50
SIZE=64
N_ch=3

# %%
def build_resnet50():
    resnet50 = ResNet50(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = resnet50(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.003, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_resnet50()
#es = EarlyStopping(monitor= "loss", patience= 3, verbose=1)
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.70, patience=3, verbose=1, min_lr=1e-4)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Out:
# 2022-09-27 09:52:50.962726: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 3)         84
# _________________________________________________________________
# resnet50 (Functional)        (None, None, None, 2048)  23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 24,122,070
# Trainable params: 24,064,342
# Non-trainable params: 57,728
# _________________________________________________________________
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
# Fits the model on batches with real-time data augmentation
hist = model.fit(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# 2022-09-27 09:52:54.300088: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 31/31 [==============================] - 68s 2s/step - loss: 1.1983 - accuracy: 0.5207 - val_loss: 0.9307 - val_accuracy: 0.5513
#
# Epoch 00001: val_loss improved from inf to 0.93066, saving model to model.h5
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.9818 - accuracy: 0.5862 - val_loss: 1.4836 - val_accuracy: 0.5513
#
# Epoch 00002: val_loss did not improve from 0.93066
# Epoch 3/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.9142 - accuracy: 0.6265 - val_loss: 0.8767 - val_accuracy: 0.4487
#
# Epoch 00003: val_loss improved from 0.93066 to 0.87672, saving model to model.h5
# Epoch 4/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.7981 - accuracy: 0.6431 - val_loss: 18.2905 - val_accuracy: 0.5513
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.002100000018253922.
#
# Epoch 00004: val_loss did not improve from 0.87672
# Epoch 5/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.7173 - accuracy: 0.6542 - val_loss: 27.6783 - val_accuracy: 0.5513
#
# Epoch 00005: val_loss did not improve from 0.87672
# Epoch 6/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.7329 - accuracy: 0.6683 - val_loss: 20.0290 - val_accuracy: 0.5513
#
# Epoch 00006: val_loss did not improve from 0.87672
# Epoch 7/50
# 31/31 [==============================] - 60s 2s/step - loss: 0.6558 - accuracy: 0.6966 - val_loss: 6.0050 - val_accuracy: 0.5513
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0014699999475851653.
#
# Epoch 00007: val_loss did not improve from 0.87672
# Epoch 8/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.6072 - accuracy: 0.6976 - val_loss: 13.2717 - val_accuracy: 0.4487
#
# Epoch 00008: val_loss did not improve from 0.87672
# Epoch 9/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.5857 - accuracy: 0.7188 - val_loss: 9.1129 - val_accuracy: 0.5513
#
# Epoch 00009: val_loss did not improve from 0.87672
# Epoch 10/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.5386 - accuracy: 0.7384 - val_loss: 9.1631 - val_accuracy: 0.4487
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0010289999307133257.
#
# Epoch 00010: val_loss did not improve from 0.87672
# Epoch 11/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.4956 - accuracy: 0.7550 - val_loss: 3.1977 - val_accuracy: 0.4487
#
# Epoch 00011: val_loss did not improve from 0.87672
# Epoch 12/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.5040 - accuracy: 0.7707 - val_loss: 3.7044 - val_accuracy: 0.5513
#
# Epoch 00012: val_loss did not improve from 0.87672
# Epoch 13/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.4824 - accuracy: 0.7727 - val_loss: 0.8277 - val_accuracy: 0.5513
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0007202999433502554.
#
# Epoch 00013: val_loss improved from 0.87672 to 0.82765, saving model to model.h5
# Epoch 14/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.4577 - accuracy: 0.7994 - val_loss: 13.4435 - val_accuracy: 0.5513
#
# Epoch 00014: val_loss did not improve from 0.82765
# Epoch 15/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.4743 - accuracy: 0.7853 - val_loss: 5.4001 - val_accuracy: 0.5513
#
# Epoch 00015: val_loss did not improve from 0.82765
# Epoch 16/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.4535 - accuracy: 0.7928 - val_loss: 2.5131 - val_accuracy: 0.5513
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005042099684942513.
#
# Epoch 00016: val_loss did not improve from 0.82765
# Epoch 17/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.4300 - accuracy: 0.8085 - val_loss: 2.4955 - val_accuracy: 0.5513
#
# Epoch 00017: val_loss did not improve from 0.82765
# Epoch 18/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.4573 - accuracy: 0.7944 - val_loss: 4.9021 - val_accuracy: 0.5513
#
# Epoch 00018: val_loss did not improve from 0.82765
# Epoch 19/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.4454 - accuracy: 0.8100 - val_loss: 1.3188 - val_accuracy: 0.4588
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0003529469657223671.
#
# Epoch 00019: val_loss did not improve from 0.82765
# Epoch 20/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.4307 - accuracy: 0.8206 - val_loss: 2.3830 - val_accuracy: 0.5513
#
# Epoch 00020: val_loss did not improve from 0.82765
# Epoch 21/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.4265 - accuracy: 0.8085 - val_loss: 3.0273 - val_accuracy: 0.5513
#
# Epoch 00021: val_loss did not improve from 0.82765
# Epoch 22/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.4288 - accuracy: 0.8085 - val_loss: 1.5848 - val_accuracy: 0.5775
#
# Epoch 00022: val_loss did not improve from 0.82765
# Epoch 23/50
# 31/31 [==============================] - 56s 2s/step - loss: 0.4203 - accuracy: 0.8160 - val_loss: 0.8811 - val_accuracy: 0.6519
#
# Epoch 00023: val_loss did not improve from 0.82765
# Epoch 24/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.4033 - accuracy: 0.8160 - val_loss: 0.6428 - val_accuracy: 0.6942
#
# Epoch 00024: val_loss improved from 0.82765 to 0.64284, saving model to model.h5
# Epoch 25/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.4242 - accuracy: 0.8185 - val_loss: 0.5872 - val_accuracy: 0.7042
#
# Epoch 00025: val_loss improved from 0.64284 to 0.58717, saving model to model.h5
# Epoch 26/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.4286 - accuracy: 0.8065 - val_loss: 0.6407 - val_accuracy: 0.6901
#
# Epoch 00026: val_loss did not improve from 0.58717
# Epoch 27/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.4271 - accuracy: 0.8080 - val_loss: 0.6817 - val_accuracy: 0.6861
#
# Epoch 00027: val_loss did not improve from 0.58717
# Epoch 28/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.4085 - accuracy: 0.8150 - val_loss: 0.6928 - val_accuracy: 0.6740
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002470628678565845.
#
# Epoch 00028: val_loss did not improve from 0.58717
# Epoch 29/50
# 31/31 [==============================] - 59s 2s/step - loss: 0.3909 - accuracy: 0.8296 - val_loss: 0.7365 - val_accuracy: 0.6640
#
# Epoch 00029: val_loss did not improve from 0.58717
# Epoch 30/50
# 31/31 [==============================] - 60s 2s/step - loss: 0.4070 - accuracy: 0.8246 - val_loss: 0.7467 - val_accuracy: 0.6740
#
# Epoch 00030: val_loss did not improve from 0.58717
# Epoch 31/50
# 31/31 [==============================] - 59s 2s/step - loss: 0.4025 - accuracy: 0.8311 - val_loss: 0.6947 - val_accuracy: 0.6841
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00017294401768594978.
#
# Epoch 00031: val_loss did not improve from 0.58717
# Epoch 32/50
# 31/31 [==============================] - 60s 2s/step - loss: 0.3863 - accuracy: 0.8276 - val_loss: 0.6752 - val_accuracy: 0.6962
#
# Epoch 00032: val_loss did not improve from 0.58717
# Epoch 33/50
# 31/31 [==============================] - 60s 2s/step - loss: 0.3968 - accuracy: 0.8291 - val_loss: 0.6664 - val_accuracy: 0.7082
#
# Epoch 00033: val_loss did not improve from 0.58717
# Epoch 34/50
# 31/31 [==============================] - 60s 2s/step - loss: 0.3918 - accuracy: 0.8306 - val_loss: 0.6318 - val_accuracy: 0.7284
#
# Epoch 00034: val_loss did not improve from 0.58717
# Epoch 35/50
# 31/31 [==============================] - 59s 2s/step - loss: 0.3965 - accuracy: 0.8231 - val_loss: 0.5603 - val_accuracy: 0.7505
#
# Epoch 00035: val_loss improved from 0.58717 to 0.56030, saving model to model.h5
# Epoch 36/50
# 31/31 [==============================] - 60s 2s/step - loss: 0.3805 - accuracy: 0.8332 - val_loss: 0.5220 - val_accuracy: 0.7686
#
# Epoch 00036: val_loss improved from 0.56030 to 0.52205, saving model to model.h5
# Epoch 37/50
# 31/31 [==============================] - 60s 2s/step - loss: 0.3914 - accuracy: 0.8291 - val_loss: 0.4906 - val_accuracy: 0.7907
#
# Epoch 00037: val_loss improved from 0.52205 to 0.49062, saving model to model.h5
# Epoch 38/50
# 31/31 [==============================] - 60s 2s/step - loss: 0.3932 - accuracy: 0.8301 - val_loss: 0.4659 - val_accuracy: 0.8068
#
# Epoch 00038: val_loss improved from 0.49062 to 0.46592, saving model to model.h5
# Epoch 39/50
# 31/31 [==============================] - 59s 2s/step - loss: 0.3976 - accuracy: 0.8155 - val_loss: 0.4404 - val_accuracy: 0.8169
#
# Epoch 00039: val_loss improved from 0.46592 to 0.44043, saving model to model.h5
# Epoch 40/50
# 31/31 [==============================] - 59s 2s/step - loss: 0.3945 - accuracy: 0.8332 - val_loss: 0.4360 - val_accuracy: 0.8189
#
# Epoch 00040: val_loss improved from 0.44043 to 0.43595, saving model to model.h5
# Epoch 41/50
# 31/31 [==============================] - 59s 2s/step - loss: 0.3884 - accuracy: 0.8296 - val_loss: 0.3846 - val_accuracy: 0.8410
#
# Epoch 00041: val_loss improved from 0.43595 to 0.38458, saving model to model.h5
# Epoch 42/50
# 31/31 [==============================] - 60s 2s/step - loss: 0.3846 - accuracy: 0.8357 - val_loss: 0.3604 - val_accuracy: 0.8431
#
# Epoch 00042: val_loss improved from 0.38458 to 0.36044, saving model to model.h5
# Epoch 43/50
# 31/31 [==============================] - 63s 2s/step - loss: 0.3883 - accuracy: 0.8372 - val_loss: 0.3522 - val_accuracy: 0.8410
#
# Epoch 00043: val_loss improved from 0.36044 to 0.35219, saving model to model.h5
# Epoch 44/50
# 31/31 [==============================] - 60s 2s/step - loss: 0.3752 - accuracy: 0.8301 - val_loss: 0.3453 - val_accuracy: 0.8471
#
# Epoch 00044: val_loss improved from 0.35219 to 0.34525, saving model to model.h5
# Epoch 45/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.3835 - accuracy: 0.8291 - val_loss: 0.3422 - val_accuracy: 0.8491
#
# Epoch 00045: val_loss improved from 0.34525 to 0.34222, saving model to model.h5
# Epoch 46/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.3855 - accuracy: 0.8342 - val_loss: 0.3410 - val_accuracy: 0.8491
#
# Epoch 00046: val_loss improved from 0.34222 to 0.34102, saving model to model.h5
# Epoch 47/50
# 31/31 [==============================] - 58s 2s/step - loss: 0.3953 - accuracy: 0.8301 - val_loss: 0.3393 - val_accuracy: 0.8592
#
# Epoch 00047: val_loss improved from 0.34102 to 0.33933, saving model to model.h5
# Epoch 48/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.3782 - accuracy: 0.8352 - val_loss: 0.3443 - val_accuracy: 0.8511
#
# Epoch 00048: val_loss did not improve from 0.33933
# Epoch 49/50
# 31/31 [==============================] - 57s 2s/step - loss: 0.4010 - accuracy: 0.8296 - val_loss: 0.3452 - val_accuracy: 0.8431
#
# Epoch 00049: val_loss did not improve from 0.33933
# Epoch 50/50
# 31/31 [==============================] - 59s 2s/step - loss: 0.3773 - accuracy: 0.8448 - val_loss: 0.3346 - val_accuracy: 0.8551
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.00012106080830562859.
#
# Epoch 00050: val_loss improved from 0.33933 to 0.33456, saving model to model.h5

# %%
model = load_model('./model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 16/16 [==============================] - 6s 252ms/step - loss: 0.3346 - accuracy: 0.8551
# Final Loss: 0.33455565571784973, Final Accuracy: 0.8551307916641235

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 8))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 51.0, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from skimage import io
from keras.preprocessing import image
img = image.load_img('../input/sarscov2-ctscan-dataset/non-COVID/Non-Covid (100).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('../input/sarscov2-ctscan-dataset/non-COVID/Non-Covid (100).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [0.43176723 0.5682328 ]
# Prediction: Non Covid-19

# %%
from skimage import io
from keras.preprocessing import image
img = image.load_img('../input/sarscov2-ctscan-dataset/COVID/Covid (100).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('../input/sarscov2-ctscan-dataset/COVID/Covid (100).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [0.8984409  0.10155904]
# Prediction: Covid-19
